# %%
# importing dependencies
import pandas as pd

import psycopg2

# %%
# creating connection to database 
conn = psycopg2.connect(
    host="mypostgresdb.ckmzzavm8bgu.us-east-1.rds.amazonaws.com",
    database="EV_DB",
    user="root",
    password="postgres")

# %%
#sample query
sql_query = """
SELECT * 
FROM clean_table
"""

# %%
# checking my dataframe
EV_stations_df = pd.read_sql(sql_query, conn)
EV_stations_df.sample(n=10)
# Out:
#               id                    city province_id  \
# 678   1124001973        Asphodel-Norwood          ON
# 1090  1124000366           Ellice-Archie          MB
# 45    1124993674              Terrebonne          QC
# 1013  1124944084              Maskinongé          QC
# 48    1124521303                 Moncton          NB
# 946   1124776153                 Trenton          NS
# 592   1124841556               Deer Lake          NL
# 280   1124000877  Saint-Charles-Borromée          QC
# 969   1124001018                Dufferin          MB
# 599   1124001817              Saint-Paul          QC
#
#                   province_name  city_population  median_income  \
# 678                     Ontario             4109          41200
# 1090                   Manitoba             2011          39200
# 45                       Quebec           111575          40800
# 1013                     Quebec             2253          40800
# 48                New Brunswick           108620          37600
# 946                 Nova Scotia             2474          38000
# 592   Newfoundland and Labrador             5249          36800
# 280                      Quebec            13321          40800
# 969                    Manitoba             2435          39200
# 599                      Quebec             5122          40800
#
#       unemployment_rate  city_electricity_rate  city_ev_registrations  \
# 678                 9.4                   13.0                     12
# 1090                7.6                    9.9                      0
# 45                  7.2                    7.3                      0
# 1013                7.2                    7.3                      0
# 48                  9.6                   12.7                      0
# 946                 7.9                   17.1                      0
# 592                12.5                   13.8                      0
# 280                 7.2                    7.3                      0
# 969                 7.6                    9.9                      0
# 599                 7.2                    7.3                      0
#
#       city_ev_stations_locations incentives_status  ev_per_province  \
# 678                            0                NO           144128
# 1090                           0               YES             3290
# 45                            27               YES           252020
# 1013                           2               YES           252020
# 48                            13               YES             2112
# 946                            0               YES                0
# 592                            2               YES                0
# 280                            4               YES           252020
# 969                            1               YES             3290
# 599                            1               YES           252020
#
#       no_certificate_perc  secondary_hs_perc  apprenticeship_per  \
# 678                  17.5               27.4                 6.0
# 1090                 22.0               29.6                 7.7
# 45                   19.9               21.5                16.9
# 1013                 19.9               21.5                16.9
# 48                   22.0               28.5                 9.1
# 946                  19.8               25.3                 9.9
# 592                  23.4               25.0                11.3
# 280                  19.9               21.5                16.9
# 969                  22.0               29.6                 7.7
# 599                  19.9               21.5                16.9
#
#       college_cegep_perc  univ_diploma_below_bachelor_per  \
# 678                 20.8                              2.2
# 1090                17.7                              2.9
# 45                  17.6                              3.6
# 1013                17.6                              3.6
# 48                  21.8                              1.9
# 946                 21.8                              2.4
# 592                 23.1                              2.4
# 280                 17.6                              3.6
# 969                 17.7                              2.9
# 599                 17.6                              3.6
#
#       univ_diploma_above_bachelor_per
# 678                              26.0
# 1090                             20.1
# 45                               20.5
# 1013                             20.5
# 48                               16.7
# 946                              20.8
# 592                              14.8
# 280                              20.5
# 969                              20.1
# 599                              20.5

# %%
# Import dependencies
import pandas as pd
from sqlalchemy import create_engine
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.inspection import permutation_importance
# import r2_score module
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
# Copy original EV_stations_df DataFrame to features_df
features_df = EV_stations_df.copy()
features_df.head()
# Out:
#            id       city province_id     province_name  city_population  \
# 0  1124279679    Toronto          ON           Ontario          5429524
# 1  1124586170   Montreal          QC            Quebec          3519595
# 2  1124825478  Vancouver          BC  British Columbia          2264823
# 3  1124690423    Calgary          AB           Alberta          1239220
# 4  1124290735   Edmonton          AB           Alberta          1062643
#
#    median_income  unemployment_rate  city_electricity_rate  \
# 0          41200                9.4                   13.0
# 1          40800                7.2                    7.3
# 2          40800                7.4                   12.6
# 3          44800               10.9                   16.6
# 4          44800               10.9                   16.6
#
#    city_ev_registrations  city_ev_stations_locations incentives_status  \
# 0                  54739                         294                NO
# 1                  61203                         709               YES
# 2                  68894                         218               YES
# 3                      0                          93               YES
# 4                      0                          70               YES
#
#    ev_per_province  no_certificate_perc  secondary_hs_perc  \
# 0           144128                 17.5               27.4
# 1           252020                 19.9               21.5
# 2           148116                 15.5               29.4
# 3                0                 16.9               27.9
# 4                0                 16.9               27.9
#
#    apprenticeship_per  college_cegep_perc  univ_diploma_below_bachelor_per  \
# 0                 6.0                20.8                              2.2
# 1                16.9                17.6                              3.6
# 2                 8.8                18.1                              3.6
# 3                 9.7                19.2                              3.0
# 4                 9.7                19.2                              3.0
#
#    univ_diploma_above_bachelor_per
# 0                             26.0
# 1                             20.5
# 2                             24.6
# 3                             23.4
# 4                             23.4

# %%
# Drop the columns identifying each city: id, city, province_id, province_name
features_df = features_df.drop(columns=["id", "province_id", "city", "province_name"])

features_df.head(10)
# Out:
#    city_population  median_income  unemployment_rate  city_electricity_rate  \
# 0          5429524          41200                9.4                   13.0
# 1          3519595          40800                7.2                    7.3
# 2          2264823          40800                7.4                   12.6
# 3          1239220          44800               10.9                   16.6
# 4          1062643          44800               10.9                   16.6
# 5           989567          41200                9.4                   13.0
# 6           721599          41200                9.4                   13.0
# 7           705244          39200                7.6                    9.9
# 8           705103          40800                7.2                    7.3
# 9           693645          41200                9.4                   13.0
#
#    city_ev_registrations  city_ev_stations_locations incentives_status  \
# 0                  54739                         294                NO
# 1                  61203                         709               YES
# 2                  68894                         218               YES
# 3                      0                          93               YES
# 4                      0                          70               YES
# 5                   6091                         159                NO
# 6                   4863                         171                NO
# 7                      0                          45               YES
# 8                      0                         149               YES
# 9                   7616                          43                NO
#
#    ev_per_province  no_certificate_perc  secondary_hs_perc  \
# 0           144128                 17.5               27.4
# 1           252020                 19.9               21.5
# 2           148116                 15.5               29.4
# 3                0                 16.9               27.9
# 4                0                 16.9               27.9
# 5           144128                 17.5               27.4
# 6           144128                 17.5               27.4
# 7             3290                 22.0               29.6
# 8           252020                 19.9               21.5
# 9           144128                 17.5               27.4
#
#    apprenticeship_per  college_cegep_perc  univ_diploma_below_bachelor_per  \
# 0                 6.0                20.8                              2.2
# 1                16.9                17.6                              3.6
# 2                 8.8                18.1                              3.6
# 3                 9.7                19.2                              3.0
# 4                 9.7                19.2                              3.0
# 5                 6.0                20.8                              2.2
# 6                 6.0                20.8                              2.2
# 7                 7.7                17.7                              2.9
# 8                16.9                17.6                              3.6
# 9                 6.0                20.8                              2.2
#
#    univ_diploma_above_bachelor_per
# 0                             26.0
# 1                             20.5
# 2                             24.6
# 3                             23.4
# 4                             23.4
# 5                             26.0
# 6                             26.0
# 7                             20.1
# 8                             20.5
# 9                             26.0

# %%
# Save categorical variable column incentives_status to variable for encoding
incentives = features_df.dtypes[features_df.dtypes == "object"].index.tolist()

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable column incentive_status
encode_df = pd.DataFrame(enc.fit_transform(features_df[incentives]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names_out(incentives)

# %%
# Merge the incentive_status_YES column back to original dataframe and drop the original incentives_status column
features_df = features_df.merge(encode_df, left_index=True, right_index=True)
features_df = features_df.drop(columns=["incentives_status", "incentives_status_NO"], axis=1)

# %%
# Split preprocessed data and define target variable and features
y = features_df["city_ev_stations_locations"]
X = features_df.drop(["city_ev_stations_locations"],axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Use RandomForestRegressor model

# %%
# Define the model
regr = RandomForestRegressor()

# Fit the model
regr_model = regr.fit(X_train_scaled, y_train)

# Make predictions
y_pred = regr_model.predict(X_test_scaled)
print(y_pred.shape)
# Out:
# (426,)

# %%
# predict the accuracy score
score = r2_score(y_test, y_pred)
print('r2 score is: ', score)
print('mean squared error is : ', mean_squared_error(y_test, y_pred))
print('root mean squared error is : ', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# r2 score is:  0.7285210497970256
# mean squared error is :  14.040212562243836
# root mean squared error is :  3.747027163264744

# %%
print(y_pred)
# Out:
# [2.65000000e+00 1.75000000e+00 7.70000000e-01 2.37333333e-01
#  4.20000000e-01 3.67000000e+00 9.50000000e-01 4.94000000e+00
#  3.26000000e+00 2.40000000e-01 1.30000000e-01 2.30000000e-01
#  0.00000000e+00 2.66500000e+01 6.50000000e-01 2.55000000e+00
#  5.60000000e-01 2.67000000e+00 1.84000000e+00 2.60000000e-01
#  4.09000000e+00 3.02000000e+00 1.59000000e+00 8.20000000e-01
#  2.29000000e+00 7.16000000e+00 4.00000000e-02 7.60000000e-01
#  0.00000000e+00 3.93000000e+00 1.28400000e+01 2.48333333e-02
#  9.10000000e-01 3.20000000e-01 2.79000000e+00 2.00000000e-02
#  1.20000000e-01 2.68166667e-01 1.80000000e-01 8.40000000e-01
#  1.63333333e-01 1.20000000e+00 7.00000000e-02 1.16000000e+00
#  9.30000000e-01 8.30000000e-01 4.30000000e-01 2.33333333e-02
#  1.63333333e-01 6.00000000e-02 5.80000000e-01 4.80000000e-01
#  0.00000000e+00 5.32000000e+00 1.24000000e+00 2.72800000e+01
#  1.02900000e+01 2.25000000e+00 3.60000000e+00 5.65000000e+00
#  4.93000000e+00 6.12800000e+01 7.96666667e-01 0.00000000e+00
#  8.00000000e-02 6.10000000e-01 1.36000000e+00 2.25000000e+00
#  7.30000000e-01 4.00000000e-02 5.40000000e-01 1.00000000e-02
#  0.00000000e+00 5.73833333e-01 7.00000000e-02 8.15000000e-01
#  1.40000000e-01 1.00000000e-02 1.00000000e-01 9.00000000e-02
#  1.34000000e+00 2.96000000e+00 8.81833333e-01 1.52000000e+00
#  2.46200000e+01 1.53000000e+00 2.00000000e-01 1.40166667e+00
#  4.22000000e+00 2.32000000e+01 6.24833333e-01 3.70000000e-01
#  6.00000000e-01 0.00000000e+00 7.26000000e+00 4.33000000e+00
#  1.21833333e-01 4.19000000e+00 1.00000000e-02 0.00000000e+00
#  4.52916667e+00 1.27300000e+01 6.31666667e-02 7.40000000e-01
#  9.45166667e-01 1.61000000e+00 2.99000000e+00 1.55000000e+00
#  7.26000000e+00 1.22000000e+00 8.00000000e-01 6.98166667e-01
#  1.91000000e+00 6.20000000e-01 1.08000000e+01 4.36000000e+00
#  1.28000000e+00 2.11500000e+01 1.65250000e+00 1.30000000e+00
#  1.00000000e-02 4.42000000e+00 4.00000000e-01 2.53000000e+00
#  5.57333333e-01 2.44000000e+00 6.60000000e-01 9.70000000e-01
#  8.00000000e-02 5.01000000e+00 3.37000000e+00 4.54000000e+00
#  1.90000000e-01 4.13000000e+00 6.00000000e-01 2.60000000e-01
#  5.56666667e-02 5.59000000e+00 3.30000000e-01 5.44833333e-01
#  3.40000000e-01 7.91000000e+00 1.18000000e+00 2.60000000e+00
#  3.82000000e+00 4.90000000e-01 6.00000000e-01 3.23800000e+01
#  2.80000000e-01 1.29000000e+00 2.28400000e+01 4.59833333e-01
#  1.99833333e-01 4.40000000e-01 1.65000000e+00 2.17000000e+00
#  1.27000000e+00 7.70000000e-01 0.00000000e+00 1.30000000e-01
#  7.33000000e+00 0.00000000e+00 1.00528571e+00 9.20000000e-01
#  2.93000000e+00 5.53000000e+00 7.91000000e+00 7.40000000e-01
#  0.00000000e+00 2.38333333e-01 1.11600000e+01 5.30000000e-01
#  1.18000000e+00 1.43000000e+00 7.00000000e-01 3.70000000e-01
#  3.76500000e-01 0.00000000e+00 1.50000000e-01 6.00000000e-01
#  1.51000000e+00 1.60000000e-01 1.27250000e+00 8.90000000e-01
#  7.94000000e+00 0.00000000e+00 1.22000000e+00 3.60000000e+00
#  1.58000000e+00 5.75000000e+00 4.13738095e-01 6.00000000e-01
#  1.00000000e-01 9.90000000e-01 1.42000000e+00 3.10000000e-01
#  1.57000000e+00 9.80000000e-01 0.00000000e+00 2.20000000e-01
#  7.30000000e-01 4.40000000e-01 6.20000000e-01 1.00000000e+00
#  3.90000000e-01 5.44166667e-01 2.98000000e+00 1.19000000e+00
#  9.40000000e-01 7.33333333e-02 2.33333333e-02 4.50000000e-01
#  1.82000000e+00 1.31600000e+01 5.43333333e-01 1.83000000e+00
#  2.30000000e-01 0.00000000e+00 2.51000000e+00 5.20000000e-01
#  4.80000000e-01 1.38000000e+00 1.14516667e+00 4.20000000e-01
#  6.00000000e-02 7.40000000e-01 2.17000000e+00 1.63333333e-01
#  3.00000000e-01 4.00000000e-02 7.10000000e-01 3.20000000e-01
#  6.50000000e-01 1.57000000e+00 2.99000000e+00 5.03000000e+00
#  1.52000000e+00 3.00000000e-01 2.08571429e-02 3.42000000e+00
#  6.00000000e-02 1.25000000e+00 4.80000000e-01 0.00000000e+00
#  1.85000000e+00 1.67000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.19000000e+00 3.67000000e+00 0.00000000e+00
#  2.50000000e-01 2.78333333e-01 3.30000000e-01 8.50000000e-01
#  3.00000000e-01 4.30000000e-01 4.17000000e+00 0.00000000e+00
#  2.19600000e+01 4.00000000e-01 2.76000000e+00 4.00000000e-02
#  8.89000000e+00 1.20000000e-01 4.95333333e-01 1.83000000e+00
#  8.90000000e-01 2.44000000e+00 1.65000000e+00 1.20000000e-01
#  9.80000000e-01 2.20000000e-01 1.11000000e+00 0.00000000e+00
#  2.00000000e-02 2.10000000e-01 7.20000000e-01 1.25200000e+01
#  1.50000000e+00 8.40000000e-01 3.12900000e+01 0.00000000e+00
#  0.00000000e+00 3.36000000e+00 3.00000000e-02 4.29000000e+00
#  2.39000000e+00 0.00000000e+00 3.10000000e-01 1.35000000e+00
#  1.79166667e-01 3.14000000e+00 2.10000000e-01 1.01800000e+01
#  5.10000000e-01 3.50000000e-01 6.00000000e-02 1.60000000e-01
#  6.10000000e-01 6.34000000e+00 9.30000000e-01 4.02000000e+00
#  9.80000000e-01 2.00000000e-01 3.30000000e-01 1.13000000e+00
#  2.70000000e-01 2.80000000e-01 3.87000000e+00 6.10000000e-01
#  0.00000000e+00 5.15000000e-01 9.40000000e-01 2.83000000e+00
#  9.68000000e+00 1.63000000e+00 6.30000000e-01 5.30000000e-01
#  8.96000000e+00 6.85000000e-02 3.00000000e-01 6.83000000e+00
#  6.10000000e-01 2.00000000e-02 8.00000000e-01 3.23000000e+00
#  8.20000000e-01 2.40000000e-01 3.18000000e+00 3.60000000e-01
#  3.95000000e+00 7.10000000e-01 0.00000000e+00 2.00000000e-01
#  7.26000000e+00 3.80000000e-01 5.45000000e+00 3.30000000e-01
#  1.50000000e-01 2.06000000e+00 6.98166667e-01 1.17000000e+02
#  6.87500000e-01 3.00000000e-02 1.80000000e-01 7.50000000e-01
#  1.16000000e+00 9.10000000e-01 4.70000000e-01 2.26000000e+00
#  2.82200000e+01 1.52000000e+00 3.38000000e+00 2.80000000e-01
#  1.53000000e+00 3.10500000e+01 1.90000000e-01 6.60000000e-01
#  1.00000000e-02 2.65000000e+00 0.00000000e+00 6.90000000e-01
#  2.00000000e-02 2.80000000e-01 2.07000000e+00 1.15583333e+00
#  1.33600000e+01 2.00000000e-02 0.00000000e+00 2.95000000e+00
#  0.00000000e+00 2.90000000e-01 1.55300000e+00 1.61000000e+00
#  2.56000000e+00 0.00000000e+00 1.70000000e-01 7.70000000e-01
#  2.42000000e+00 2.80000000e-01 1.22000000e+00 9.80000000e-01
#  1.89000000e+00 3.51000000e+00 5.91900000e+01 5.30000000e-01
#  5.20000000e-01 2.20000000e-01 2.63000000e+00 0.00000000e+00
#  1.10516667e+00 2.00000000e-01 3.07000000e+00 3.40000000e-01
#  1.64000000e+00 6.60000000e-01 3.85333333e-01 2.13900000e+01
#  8.40000000e-01 2.22000000e+00 4.00000000e-01 2.97000000e+00
#  1.66000000e+00 1.62000000e+00 8.90000000e-01 2.60000000e+00
#  0.00000000e+00 2.21000000e+00 3.31000000e+00 1.13000000e+00
#  1.46000000e+00 1.00000000e-01 4.70000000e-01 2.20000000e-01
#  1.79166667e-01 3.90000000e-01 7.50000000e-01 5.70000000e-01
#  5.48000000e+00 6.50000000e-01 0.00000000e+00 0.00000000e+00
#  4.00000000e-02 1.20000000e-01]

# %%
# check score
regr_model.score(X_test_scaled, y_test)
# Out:
# 0.7285210497970256

# %%
# Generate feature importances
feature_columns = features_df.drop(["city_ev_stations_locations"], axis=1)
feature_names = list(feature_columns.columns.values)
importances = permutation_importance(regr, X_test, y_test, n_repeats=10, random_state =78, n_jobs=2)

feature_importances = pd.Series(importances.importances_mean, index=feature_names)

# %%
# Plot feature importance
fig, ax = plt.subplots()
feature_importances.plot.bar(yerr=importances.importances_std, ax=ax)
ax.set_title("Feature importances using permutation on full model")
ax.set_ylabel("Mean accuracy decrease")
fig.tight_layout()
plt.show()

# %%
# Save the model
import pickle

# Save the trained model
EV_station_predictions = "station_prediction_model.pkl"

with open(EV_station_predictions, 'wb') as file:
    pickle.dump(regr_model, file)

# %%
# Load the model
with open(EV_station_predictions, 'rb') as file:
    prediction_model = pickle.load(file)

prediction_model
# Out:
# RandomForestRegressor()

# %%
full_preds = prediction_model.predict(X_train_scaled)
print(full_preds.shape)
full_preds
# Out:
# (1278,)
# array([ 0.  ,  6.66,  0.05, ..., 28.09,  0.66,  0.07])

# %%
exist_train = pd.DataFrame(y_train)
exist_train
# Out:
#       city_ev_stations_locations
# 1354                           0
# 298                            8
# 1660                           0
# 49                            18
# 623                            2
# ...                          ...
# 310                            0
# 105                            0
# 40                            31
# 470                            0
# 709                            0
#
# [1278 rows x 1 columns]

# %%
train_predictions = exist_train
train_predictions["model_predictions"] = full_preds
train_predictions
# Out:
#       city_ev_stations_locations  model_predictions
# 1354                           0               0.00
# 298                            8               6.66
# 1660                           0               0.05
# 49                            18              14.74
# 623                            2               1.68
# ...                          ...                ...
# 310                            0               0.75
# 105                            0               2.34
# 40                            31              28.09
# 470                            0               0.66
# 709                            0               0.07
#
# [1278 rows x 2 columns]

# %%
# Merge the training predictions and the EV_stations_df
EV_train_predictions = EV_stations_df.merge(train_predictions, left_index=True, right_index=True)
EV_train_predictions = EV_train_predictions.drop(columns="city_ev_stations_locations_x", axis=1)
EV_train_predictions
# Out:
#               id             city province_id     province_name  \
# 0     1124279679          Toronto          ON           Ontario
# 1     1124586170         Montreal          QC            Quebec
# 2     1124825478        Vancouver          BC  British Columbia
# 3     1124690423          Calgary          AB           Alberta
# 5     1124399363           Ottawa          ON           Ontario
# ...          ...              ...         ...               ...
# 1694  1124000091       Assiginack          ON           Ontario
# 1696  1124260692      Hudson Hope          BC  British Columbia
# 1699  1124105436       Durham-Sud          QC            Quebec
# 1701  1124001339  Nipawin No. 487          SK      Saskatchewan
# 1703  1124000494             Oyen          AB           Alberta
#
#       city_population  median_income  unemployment_rate  \
# 0             5429524          41200                9.4
# 1             3519595          40800                7.2
# 2             2264823          40800                7.4
# 3             1239220          44800               10.9
# 5              989567          41200                9.4
# ...               ...            ...                ...
# 1694             1013          41200                9.4
# 1696             1012          40800                7.4
# 1699             1008          40800                7.2
# 1701             1004          42400                7.0
# 1703             1001          44800               10.9
#
#       city_electricity_rate  city_ev_registrations incentives_status  \
# 0                      13.0                  54739                NO
# 1                       7.3                  61203               YES
# 2                      12.6                  68894               YES
# 3                      16.6                      0               YES
# 5                      13.0                   6091                NO
# ...                     ...                    ...               ...
# 1694                   13.0                      1                NO
# 1696                   12.6                      0               YES
# 1699                    7.3                      0               YES
# 1701                   18.1                      0               YES
# 1703                   16.6                      0               YES
#
#       ev_per_province  no_certificate_perc  secondary_hs_perc  \
# 0              144128                 17.5               27.4
# 1              252020                 19.9               21.5
# 2              148116                 15.5               29.4
# 3                   0                 16.9               27.9
# 5              144128                 17.5               27.4
# ...               ...                  ...                ...
# 1694           144128                 17.5               27.4
# 1696           148116                 15.5               29.4
# 1699           252020                 19.9               21.5
# 1701             2222                 20.7               30.5
# 1703                0                 16.9               27.9
#
#       apprenticeship_per  college_cegep_perc  univ_diploma_below_bachelor_per  \
# 0                    6.0                20.8                              2.2
# 1                   16.9                17.6                              3.6
# 2                    8.8                18.1                              3.6
# 3                    9.7                19.2                              3.0
# 5                    6.0                20.8                              2.2
# ...                  ...                 ...                              ...
# 1694                 6.0                20.8                              2.2
# 1696                 8.8                18.1                              3.6
# 1699                16.9                17.6                              3.6
# 1701                10.4                17.1                              3.3
# 1703                 9.7                19.2                              3.0
#
#       univ_diploma_above_bachelor_per  city_ev_stations_locations_y  \
# 0                                26.0                           294
# 1                                20.5                           709
# 2                                24.6                           218
# 3                                23.4                            93
# 5                                26.0                           159
# ...                               ...                           ...
# 1694                             26.0                             0
# 1696                             24.6                             0
# 1699                             20.5                             0
# 1701                             18.0                             0
# 1703                             23.4                             0
#
#       model_predictions
# 0                389.64
# 1                552.40
# 2                318.65
# 3                114.48
# 5                149.79
# ...                 ...
# 1694               0.01
# 1696               0.10
# 1699               0.00
# 1701               0.44
# 1703               0.00
#
# [1278 rows x 19 columns]

# %%
# Save prediction DataFrame to csv file
# Create filepath
filepath = Path('..\Datasets\Training_Station_Predictions.csv')

# Save the file
EV_train_predictions.to_csv(filepath)

# %%
existing = pd.DataFrame(y_test)
existing
# Out:
#       city_ev_stations_locations
# 220                            5
# 504                            3
# 488                            0
# 1262                           5
# 1135                           0
# ...                          ...
# 693                            7
# 1109                           0
# 1189                           0
# 990                            0
# 622                            0
#
# [426 rows x 1 columns]

# %%
predictions_df = existing
predictions_df["model_predictions"] = y_pred
predictions_df
# Out:
#       city_ev_stations_locations  model_predictions
# 220                            5               2.80
# 504                            3               1.69
# 488                            0               1.01
# 1262                           5               0.12
# 1135                           0               0.33
# ...                          ...                ...
# 693                            7               0.59
# 1109                           0               0.00
# 1189                           0               0.00
# 990                            0               0.13
# 622                            0               0.21
#
# [426 rows x 2 columns]

# %%
# Merge the training predictions and the EV_stations_df
EV_test_predictions = EV_stations_df.merge(predictions_df, left_index=True, right_index=True)
EV_test_predictions = EV_test_predictions.drop(columns="city_ev_stations_locations_x", axis=1)
EV_test_predictions
# Out:
#               id               city province_id     province_name  \
# 4     1124290735           Edmonton          AB           Alberta
# 12    1124158530          Kitchener          ON           Ontario
# 19    1124704011      Niagara Falls          ON           Ontario
# 22    1124261024            Windsor          ON           Ontario
# 25    1124817304            Burnaby          BC  British Columbia
# ...          ...                ...         ...               ...
# 1695  1124001084            Brébeuf          QC            Quebec
# 1697  1124000733             Prince          ON           Ontario
# 1698  1124218916     Baie-du-Febvre          QC            Quebec
# 1700  1124850489          Melbourne          QC            Quebec
# 1702  1124001661  Duck Lake No. 463          SK      Saskatchewan
#
#       city_population  median_income  unemployment_rate  \
# 4             1062643          44800               10.9
# 12             470015          41200                9.4
# 19             308596          41200                9.4
# 22             276165          41200                9.4
# 25             232755          40800                7.4
# ...               ...            ...                ...
# 1695             1012          40800                7.2
# 1697             1010          41200                9.4
# 1698             1010          40800                7.2
# 1700             1004          40800                7.2
# 1702             1004          42400                7.0
#
#       city_electricity_rate  city_ev_registrations incentives_status  \
# 4                      16.6                      0               YES
# 12                     13.0                   1231                NO
# 19                     13.0                    269                NO
# 22                     13.0                   1601                NO
# 25                     12.6                   4454               YES
# ...                     ...                    ...               ...
# 1695                    7.3                      0               YES
# 1697                   13.0                      0                NO
# 1698                    7.3                      0               YES
# 1700                    7.3                      0               YES
# 1702                   18.1                      0               YES
#
#       ev_per_province  no_certificate_perc  secondary_hs_perc  \
# 4                   0                 16.9               27.9
# 12             144128                 17.5               27.4
# 19             144128                 17.5               27.4
# 22             144128                 17.5               27.4
# 25             148116                 15.5               29.4
# ...               ...                  ...                ...
# 1695           252020                 19.9               21.5
# 1697           144128                 17.5               27.4
# 1698           252020                 19.9               21.5
# 1700           252020                 19.9               21.5
# 1702             2222                 20.7               30.5
#
#       apprenticeship_per  college_cegep_perc  univ_diploma_below_bachelor_per  \
# 4                    9.7                19.2                              3.0
# 12                   6.0                20.8                              2.2
# 19                   6.0                20.8                              2.2
# 22                   6.0                20.8                              2.2
# 25                   8.8                18.1                              3.6
# ...                  ...                 ...                              ...
# 1695                16.9                17.6                              3.6
# 1697                 6.0                20.8                              2.2
# 1698                16.9                17.6                              3.6
# 1700                16.9                17.6                              3.6
# 1702                10.4                17.1                              3.3
#
#       univ_diploma_above_bachelor_per  city_ev_stations_locations_y  \
# 4                                23.4                            70
# 12                               26.0                            38
# 19                               26.0                            18
# 22                               26.0                            33
# 25                               24.6                            71
# ...                               ...                           ...
# 1695                             20.5                             0
# 1697                             26.0                             0
# 1698                             20.5                             1
# 1700                             20.5                             1
# 1702                             18.0                             0
#
#       model_predictions
# 4                115.92
# 12                55.78
# 19                28.08
# 22                31.29
# 25                57.05
# ...                 ...
# 1695               0.00
# 1697               0.00
# 1698               0.00
# 1700               0.00
# 1702               0.44
#
# [426 rows x 19 columns]

# %%
# Save prediction DataFrame to csv file
# Create filepath
filepath = Path('..\Datasets\Testing_Station_Predictions.csv')

# Save the file
EV_test_predictions.to_csv(filepath)
